# %% [raw]
# In this notebook, we create new features that help
# machine learning models understand time dependencies and seasonal behavior in electricity demand.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import math
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
time = pd.read_csv(r"C:\Users\ramya\Downloads\time_series_with_external_factors.csv")

# %%
time['date'] = pd.to_datetime(time['date'])
time = time.set_index('date')

# %%
time.head()
# Out:
#             electricity_demand  temperature_celsius  rainfall_mm  is_holiday
# date
# 2019-01-01              414.34                26.17         1.85           0
# 2019-01-02              399.36                25.07        12.70           0
# 2019-01-03              391.19                26.81         8.28           0
# 2019-01-04              433.55                28.73         5.96           0
# 2019-01-05              428.43                25.39         2.98           1

# %% [raw]
# Time series ML models cannot automatically understand past behavior.
# We must explicitly create features such as:
# - Lag values
# - Rolling statistics
# - Calendar information

# %%
# lag features created
time['lag_1'] = time['electricity_demand'].shift(1)
time['lag_7'] = time['electricity_demand'].shift(7)
time['lag_30'] = time['electricity_demand'].shift(30)

time[['electricity_demand','lag_1','lag_7','lag_30']].head(35)
# Out:
#             electricity_demand   lag_1   lag_7  lag_30
# date
# 2019-01-01              414.34     NaN     NaN     NaN
# 2019-01-02              399.36  414.34     NaN     NaN
# 2019-01-03              391.19  399.36     NaN     NaN
# 2019-01-04              433.55  391.19     NaN     NaN
# 2019-01-05              428.43  433.55     NaN     NaN
# 2019-01-06              417.23  428.43     NaN     NaN
# 2019-01-07              443.44  417.23     NaN     NaN
# 2019-01-08              399.71  443.44  414.34     NaN
# 2019-01-09              408.87  399.71  399.36     NaN
# 2019-01-10              475.90  408.87  391.19     NaN
# 2019-01-11              428.24  475.90  433.55     NaN
# 2019-01-12              433.41  428.24  428.43     NaN
# 2019-01-13              460.03  433.41  417.23     NaN
# 2019-01-14              389.23  460.03  443.44     NaN
# 2019-01-15              408.90  389.23  399.71     NaN
# 2019-01-16              396.80  408.90  408.87     NaN
# 2019-01-17              408.01  396.80  475.90     NaN
# 2019-01-18              455.73  408.01  428.24     NaN
# 2019-01-19              428.00  455.73  433.41     NaN
# 2019-01-20              399.16  428.00  460.03     NaN
# 2019-01-21              449.82  399.16  389.23     NaN
# 2019-01-22              462.68  449.82  408.90     NaN
# 2019-01-23              411.33  462.68  396.80     NaN
# 2019-01-24              430.58  411.33  408.01     NaN
# 2019-01-25              436.01  430.58  455.73     NaN
# 2019-01-26              438.60  436.01  428.00     NaN
# 2019-01-27              411.02  438.60  399.16     NaN
# 2019-01-28              441.64  411.02  449.82     NaN
# 2019-01-29              443.81  441.64  462.68     NaN
# 2019-01-30              445.62  443.81  411.33     NaN
# 2019-01-31              429.01  445.62  430.58  414.34
# 2019-02-01              452.72  429.01  436.01  399.36
# 2019-02-02              421.28  452.72  438.60  391.19
# 2019-02-03              443.77  421.28  411.02  433.55
# 2019-02-04              473.09  443.77  441.64  428.43

# %% [raw]
# Feature Meaning
#
# lag_1 - Yesterday’s demand
#
# lag_7 - Demand one week ago
#
# lag_30 - Monthly pattern

# %%
# Creating rolling Features

# %%
time['rolling_7_mean'] = time['electricity_demand'].rolling(window=7).mean()
time['rolling_30_mean'] = time['electricity_demand'].rolling(window=30).mean()

time[['rolling_7_mean','rolling_30_mean']].head(40)
# Out:
#             rolling_7_mean  rolling_30_mean
# date
# 2019-01-01             NaN              NaN
# 2019-01-02             NaN              NaN
# 2019-01-03             NaN              NaN
# 2019-01-04             NaN              NaN
# 2019-01-05             NaN              NaN
# 2019-01-06             NaN              NaN
# 2019-01-07      418.220000              NaN
# 2019-01-08      416.130000              NaN
# 2019-01-09      417.488571              NaN
# 2019-01-10      429.590000              NaN
# 2019-01-11      428.831429              NaN
# 2019-01-12      429.542857              NaN
# 2019-01-13      435.657143              NaN
# 2019-01-14      427.912857              NaN
# 2019-01-15      429.225714              NaN
# 2019-01-16      427.501429              NaN
# 2019-01-17      417.802857              NaN
# 2019-01-18      421.730000              NaN
# 2019-01-19      420.957143              NaN
# 2019-01-20      412.261429              NaN
# 2019-01-21      420.917143              NaN
# 2019-01-22      428.600000              NaN
# 2019-01-23      430.675714              NaN
# 2019-01-24      433.900000              NaN
# 2019-01-25      431.082857              NaN
# 2019-01-26      432.597143              NaN
# 2019-01-27      434.291429              NaN
# 2019-01-28      433.122857              NaN
# 2019-01-29      430.427143              NaN
# 2019-01-30      435.325714       426.354667
# 2019-01-31      435.101429       426.843667
# 2019-02-01      437.488571       428.622333
# 2019-02-02      435.014286       429.625333
# 2019-02-03      439.692857       429.966000
# 2019-02-04      444.185714       431.454667
# 2019-02-05      440.662857       431.518667
# 2019-02-06      437.944286       430.957000
# 2019-02-07      438.691429       432.108000
# 2019-02-08      434.577143       432.609667
# 2019-02-09      439.182857       431.863667

# %% [raw]
# Why Rolling Mean?
# Smooths noise
# Captures short & long-term trends

# %%
# Createing Calendar feature

# %%
time['day'] = time.index.day
time['month'] = time.index.month
time['day_of_week'] = time.index.dayofweek
time['week_of_year'] = time.index.isocalendar().week

time[['day','month','day_of_week','week_of_year']].head()
# Out:
#             day  month  day_of_week  week_of_year
# date
# 2019-01-01    1      1            1             1
# 2019-01-02    2      1            2             1
# 2019-01-03    3      1            3             1
# 2019-01-04    4      1            4             1
# 2019-01-05    5      1            5             1

# %% [raw]
# Explanation
# day_of_week: weekday vs weekend behavior
# month: seasonal pattern
# week_of_year: yearly cycles

# %%
# Createing weekend feature
time['is_weekend'] = np.where(time['day_of_week'] >= 5, 1, 0)
time[['day_of_week','is_weekend']].head(20)
# Out:
#             day_of_week  is_weekend
# date
# 2019-01-01            1           0
# 2019-01-02            2           0
# 2019-01-03            3           0
# 2019-01-04            4           0
# 2019-01-05            5           1
# 2019-01-06            6           1
# 2019-01-07            0           0
# 2019-01-08            1           0
# 2019-01-09            2           0
# 2019-01-10            3           0
# 2019-01-11            4           0
# 2019-01-12            5           1
# 2019-01-13            6           1
# 2019-01-14            0           0
# 2019-01-15            1           0
# 2019-01-16            2           0
# 2019-01-17            3           0
# 2019-01-18            4           0
# 2019-01-19            5           1
# 2019-01-20            6           1

# %% [raw]
# Insight
# weekend often behave differently from weekdays

# %%
# Handle missing values
time.isnull().sum()
# Out:
# electricity_demand      0
# temperature_celsius     0
# rainfall_mm             0
# is_holiday              0
# lag_1                   1
# lag_7                   7
# lag_30                 30
# rolling_7_mean          6
# rolling_30_mean        29
# day                     0
# month                   0
# day_of_week             0
# week_of_year            0
# is_weekend              0
# dtype: int64

# %%
# Drop Missing Rows

time = time.dropna()
time.isna().sum()
# Out:
# electricity_demand     0
# temperature_celsius    0
# rainfall_mm            0
# is_holiday             0
# lag_1                  0
# lag_7                  0
# lag_30                 0
# rolling_7_mean         0
# rolling_30_mean        0
# day                    0
# month                  0
# day_of_week            0
# week_of_year           0
# is_weekend             0
# dtype: int64

# %%
# Feature vs Target Separation

X = time.drop('electricity_demand', axis=1)
Y = time['electricity_demand']

print("Feature shape:", X.shape)
print("Target shape:", Y.shape)
# Out:
# Feature shape: (1796, 13)
# Target shape: (1796,)

# %%
X # it will only contains feature variables
# Out:
#             temperature_celsius  rainfall_mm  is_holiday   lag_1   lag_7  \
# date
# 2019-01-31                28.88         3.04           0  445.62  430.58
# 2019-02-01                33.94         2.47           0  429.01  436.01
# 2019-02-02                30.35         6.83           1  452.72  438.60
# 2019-02-03                28.41         7.43           1  421.28  411.02
# 2019-02-04                32.31         5.02           0  443.77  441.64
# ...                         ...          ...         ...     ...     ...
# 2023-12-27                24.47        10.17           0  422.51  393.25
# 2023-12-28                24.03         3.58           0  405.44  405.71
# 2023-12-29                23.36         4.53           0  414.86  384.14
# 2023-12-30                25.17         4.23           1  396.40  418.20
# 2023-12-31                25.88        20.01           1  466.54  411.20
#
#             lag_30  rolling_7_mean  rolling_30_mean  day  month  day_of_week  \
# date
# 2019-01-31  414.34      435.101429       426.843667   31      1            3
# 2019-02-01  399.36      437.488571       428.622333    1      2            4
# 2019-02-02  391.19      435.014286       429.625333    2      2            5
# 2019-02-03  433.55      439.692857       429.966000    3      2            6
# 2019-02-04  428.43      444.185714       431.454667    4      2            0
# ...            ...             ...              ...  ...    ...          ...
# 2023-12-27  392.15      406.455714       399.983000   27     12            2
# 2023-12-28  361.87      407.762857       401.749333   28     12            3
# 2023-12-29  403.54      409.514286       401.511333   29     12            4
# 2023-12-30  393.41      416.420000       403.949000   30     12            5
# 2023-12-31  407.01      415.135714       403.789000   31     12            6
#
#             week_of_year  is_weekend
# date
# 2019-01-31             5           0
# 2019-02-01             5           0
# 2019-02-02             5           1
# 2019-02-03             5           1
# 2019-02-04             6           0
# ...                  ...         ...
# 2023-12-27            52           0
# 2023-12-28            52           0
# 2023-12-29            52           0
# 2023-12-30            52           1
# 2023-12-31            52           1
#
# [1796 rows x 13 columns]

# %%
Y # it will only can target variables
# Out:
# date
# 2019-01-31    429.01
# 2019-02-01    452.72
# 2019-02-02    421.28
# 2019-02-03    443.77
# 2019-02-04    473.09
#                ...
# 2023-12-27    405.44
# 2023-12-28    414.86
# 2023-12-29    396.40
# 2023-12-30    466.54
# 2023-12-31    402.21
# Name: electricity_demand, Length: 1796, dtype: float64

# %%
X.columns # Final Feature List
# Out:
# Index(['temperature_celsius', 'rainfall_mm', 'is_holiday', 'lag_1', 'lag_7',
#        'lag_30', 'rolling_7_mean', 'rolling_30_mean', 'day', 'month',
#        'day_of_week', 'week_of_year', 'is_weekend'],
#       dtype='object')

# %% [raw]
# Final Features Created
# Lag features
# Rolling statistics
# Weather variables
# Holiday & weekend flags
# Calendar features

# %%
time.to_csv("feature_engineered_time_series.csv")

# %% [raw]
# # Key Learning from Notebook-2
# 1. Lag features capture historical dependency
# 2. Rolling features smooth volatility
# 3. Calendar features capture seasonality
# 4. Feature engineering improves ML performance drastically
